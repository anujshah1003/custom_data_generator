# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  

import numpy as np

from keras.layers import (Activation, Conv3D, Dense, Dropout, Flatten,
                          MaxPooling3D)
from keras.layers.advanced_activations import LeakyReLU
from keras.losses import categorical_crossentropy
from keras.models import Sequential
from keras.optimizers import Adam
from keras.utils import np_utils
from keras.utils.vis_utils import plot_model
from sklearn.model_selection import train_test_split

from data_gen import DataGenerator
from config import Config
# Out:
# Using TensorFlow backend.

# %%
root_data_path='data_files'

data_gen_obj=DataGenerator(root_data_path,temporal_stride=4,temporal_length=16,resize=64)

# %%
train_data = data_gen_obj.load_samples(data_cat='train')

test_data = data_gen_obj.load_samples(data_cat='test')
# Out:
# num of samples from vid seq-Archery_v_Archery_g01_c01.csv: 29
# num of samples from vid seq-Archery_v_Archery_g01_c02.csv: 32
# num of samples from vid seq-Archery_v_Archery_g01_c03.csv: 36
# num of samples from vid seq-Archery_v_Archery_g01_c04.csv: 28
# num of samples from vid seq-Archery_v_Archery_g01_c05.csv: 30
# num of samples from vid seq-Archery_v_Archery_g01_c06.csv: 24
# num of samples from vid seq-Archery_v_Archery_g01_c07.csv: 32
# num of samples from vid seq-Archery_v_Archery_g02_c01.csv: 36
# num of samples from vid seq-Archery_v_Archery_g02_c02.csv: 37
# num of samples from vid seq-Archery_v_Archery_g02_c03.csv: 31
# num of samples from vid seq-Archery_v_Archery_g02_c04.csv: 24
# num of samples from vid seq-Archery_v_Archery_g02_c05.csv: 28
# num of samples from vid seq-Archery_v_Archery_g02_c06.csv: 25
# num of samples from vid seq-Archery_v_Archery_g02_c07.csv: 38
# num of samples from vid seq-Archery_v_Archery_g03_c01.csv: 34
# num of samples from vid seq-Archery_v_Archery_g03_c02.csv: 41
# num of samples from vid seq-Archery_v_Archery_g03_c03.csv: 28
# num of samples from vid seq-Archery_v_Archery_g03_c04.csv: 31
# num of samples from vid seq-Archery_v_Archery_g03_c05.csv: 28
# num of samples from vid seq-Archery_v_Archery_g04_c01.csv: 38
# num of samples from vid seq-Archery_v_Archery_g04_c02.csv: 40
# num of samples from vid seq-Archery_v_Archery_g04_c03.csv: 32
# num of samples from vid seq-Archery_v_Archery_g04_c04.csv: 30
# num of samples from vid seq-Archery_v_Archery_g04_c05.csv: 34
# num of samples from vid seq-Archery_v_Archery_g05_c01.csv: 110
# num of samples from vid seq-Archery_v_Archery_g05_c02.csv: 136
# num of samples from vid seq-Archery_v_Archery_g05_c03.csv: 119
# num of samples from vid seq-Archery_v_Archery_g05_c04.csv: 9
# num of samples from vid seq-Archery_v_Archery_g05_c05.csv: 46
# num of samples from vid seq-Archery_v_Archery_g06_c01.csv: 17
# num of samples from vid seq-Archery_v_Archery_g06_c02.csv: 26
# num of samples from vid seq-Archery_v_Archery_g06_c03.csv: 18
# num of samples from vid seq-Archery_v_Archery_g06_c04.csv: 23
# num of samples from vid seq-Archery_v_Archery_g06_c05.csv: 29
# num of samples from vid seq-Archery_v_Archery_g06_c06.csv: 30
# num of samples from vid seq-Archery_v_Archery_g07_c01.csv: 19
# num of samples from vid seq-Archery_v_Archery_g07_c02.csv: 15
# num of samples from vid seq-Archery_v_Archery_g07_c03.csv: 9
# num of samples from vid seq-Archery_v_Archery_g07_c04.csv: 9
# num of samples from vid seq-Archery_v_Archery_g07_c05.csv: 13
# num of samples from vid seq-Archery_v_Archery_g07_c06.csv: 13
# num of samples from vid seq-Archery_v_Archery_g08_c01.csv: 87
# num of samples from vid seq-Archery_v_Archery_g08_c02.csv: 26
# num of samples from vid seq-Archery_v_Archery_g08_c03.csv: 78
# num of samples from vid seq-Archery_v_Archery_g08_c04.csv: 82
# num of samples from vid seq-Archery_v_Archery_g08_c05.csv: 88
# num of samples from vid seq-Archery_v_Archery_g09_c01.csv: 21
# num of samples from vid seq-Archery_v_Archery_g09_c02.csv: 17
# num of samples from vid seq-Archery_v_Archery_g09_c03.csv: 17
# num of samples from vid seq-Archery_v_Archery_g09_c04.csv: 20
# num of samples from vid seq-Archery_v_Archery_g09_c05.csv: 21
# num of samples from vid seq-Archery_v_Archery_g09_c06.csv: 18
# num of samples from vid seq-Archery_v_Archery_g09_c07.csv: 23
# num of samples from vid seq-Archery_v_Archery_g10_c01.csv: 24
# num of samples from vid seq-Archery_v_Archery_g10_c02.csv: 32
# num of samples from vid seq-Archery_v_Archery_g10_c03.csv: 47
# num of samples from vid seq-Archery_v_Archery_g10_c04.csv: 49
# num of samples from vid seq-Archery_v_Archery_g10_c05.csv: 44
# num of samples from vid seq-Archery_v_Archery_g10_c06.csv: 41
# num of samples from vid seq-Archery_v_Archery_g10_c07.csv: 28
# num of samples from vid seq-Archery_v_Archery_g11_c01.csv: 45
# num of samples from vid seq-Archery_v_Archery_g11_c02.csv: 72
# num of samples from vid seq-Archery_v_Archery_g11_c03.csv: 70
# num of samples from vid seq-Archery_v_Archery_g11_c04.csv: 61
# num of samples from vid seq-Archery_v_Archery_g11_c05.csv: 49
# num of samples from vid seq-Archery_v_Archery_g11_c06.csv: 57
# num of samples from vid seq-Archery_v_Archery_g11_c07.csv: 63
# num of samples from vid seq-Archery_v_Archery_g12_c01.csv: 85
# num of samples from vid seq-Archery_v_Archery_g12_c02.csv: 96
# num of samples from vid seq-Archery_v_Archery_g12_c03.csv: 106
# num of samples from vid seq-Archery_v_Archery_g12_c04.csv: 45
# num of samples from vid seq-Archery_v_Archery_g13_c01.csv: 34
# num of samples from vid seq-Archery_v_Archery_g13_c02.csv: 33
# num of samples from vid seq-Archery_v_Archery_g13_c03.csv: 37
# num of samples from vid seq-Archery_v_Archery_g13_c04.csv: 38
# num of samples from vid seq-Archery_v_Archery_g13_c05.csv: 43
# num of samples from vid seq-Archery_v_Archery_g13_c06.csv: 38
# num of samples from vid seq-Archery_v_Archery_g13_c07.csv: 44
# num of samples from vid seq-Archery_v_Archery_g14_c01.csv: 48
# num of samples from vid seq-Archery_v_Archery_g14_c02.csv: 52
# num of samples from vid seq-Archery_v_Archery_g14_c03.csv: 39
# num of samples from vid seq-Archery_v_Archery_g14_c04.csv: 58
# num of samples from vid seq-Archery_v_Archery_g15_c01.csv: 24
# num of samples from vid seq-Archery_v_Archery_g15_c02.csv: 43
# num of samples from vid seq-Archery_v_Archery_g15_c03.csv: 43
# num of samples from vid seq-Archery_v_Archery_g15_c04.csv: 47
# num of samples from vid seq-Archery_v_Archery_g15_c05.csv: 40
# num of samples from vid seq-Archery_v_Archery_g15_c06.csv: 40
# num of samples from vid seq-Archery_v_Archery_g15_c07.csv: 40
# num of samples from vid seq-Archery_v_Archery_g16_c01.csv: 34
# num of samples from vid seq-Archery_v_Archery_g16_c02.csv: 53
# num of samples from vid seq-Archery_v_Archery_g16_c03.csv: 48
# num of samples from vid seq-Archery_v_Archery_g16_c04.csv: 26
# num of samples from vid seq-Archery_v_Archery_g16_c05.csv: 62
# num of samples from vid seq-Archery_v_Archery_g17_c01.csv: 33
# num of samples from vid seq-Archery_v_Archery_g17_c02.csv: 20
# num of samples from vid seq-Archery_v_Archery_g17_c03.csv: 21
# num of samples from vid seq-Archery_v_Archery_g17_c04.csv: 13
# num of samples from vid seq-Archery_v_Archery_g18_c01.csv: 38
# num of samples from vid seq-Archery_v_Archery_g18_c02.csv: 69
# num of samples from vid seq-Basketball_v_Basketball_g01_c01.csv: 32
# num of samples from vid seq-Basketball_v_Basketball_g01_c02.csv: 42
# num of samples from vid seq-Basketball_v_Basketball_g01_c03.csv: 48
# num of samples from vid seq-Basketball_v_Basketball_g01_c04.csv: 24
# num of samples from vid seq-Basketball_v_Basketball_g01_c05.csv: 32
# num of samples from vid seq-Basketball_v_Basketball_g01_c06.csv: 34
# num of samples from vid seq-Basketball_v_Basketball_g01_c07.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g02_c01.csv: 10
# num of samples from vid seq-Basketball_v_Basketball_g02_c02.csv: 11
# num of samples from vid seq-Basketball_v_Basketball_g02_c03.csv: 25
# num of samples from vid seq-Basketball_v_Basketball_g02_c04.csv: 17
# num of samples from vid seq-Basketball_v_Basketball_g02_c05.csv: 33
# num of samples from vid seq-Basketball_v_Basketball_g02_c06.csv: 28
# num of samples from vid seq-Basketball_v_Basketball_g03_c01.csv: 31
# num of samples from vid seq-Basketball_v_Basketball_g03_c02.csv: 28
# num of samples from vid seq-Basketball_v_Basketball_g03_c03.csv: 27
# num of samples from vid seq-Basketball_v_Basketball_g03_c04.csv: 17
# num of samples from vid seq-Basketball_v_Basketball_g03_c05.csv: 27
# num of samples from vid seq-Basketball_v_Basketball_g03_c06.csv: 18
# num of samples from vid seq-Basketball_v_Basketball_g04_c01.csv: 24
# num of samples from vid seq-Basketball_v_Basketball_g04_c02.csv: 23
# num of samples from vid seq-Basketball_v_Basketball_g04_c03.csv: 23
# num of samples from vid seq-Basketball_v_Basketball_g04_c04.csv: 15
# num of samples from vid seq-Basketball_v_Basketball_g05_c01.csv: 30
# num of samples from vid seq-Basketball_v_Basketball_g05_c02.csv: 24
# num of samples from vid seq-Basketball_v_Basketball_g05_c03.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g05_c04.csv: 18
# num of samples from vid seq-Basketball_v_Basketball_g06_c01.csv: 14
# num of samples from vid seq-Basketball_v_Basketball_g06_c02.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g06_c03.csv: 19
# num of samples from vid seq-Basketball_v_Basketball_g06_c04.csv: 16
# num of samples from vid seq-Basketball_v_Basketball_g07_c01.csv: 32
# num of samples from vid seq-Basketball_v_Basketball_g07_c02.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g07_c03.csv: 34
# num of samples from vid seq-Basketball_v_Basketball_g07_c04.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g08_c01.csv: 39
# num of samples from vid seq-Basketball_v_Basketball_g08_c02.csv: 18
# num of samples from vid seq-Basketball_v_Basketball_g08_c03.csv: 21
# num of samples from vid seq-Basketball_v_Basketball_g08_c04.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g09_c01.csv: 24
# num of samples from vid seq-Basketball_v_Basketball_g09_c02.csv: 23
# num of samples from vid seq-Basketball_v_Basketball_g09_c03.csv: 18
# num of samples from vid seq-Basketball_v_Basketball_g09_c04.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g09_c05.csv: 27
# num of samples from vid seq-Basketball_v_Basketball_g10_c01.csv: 29
# num of samples from vid seq-Basketball_v_Basketball_g10_c02.csv: 28
# num of samples from vid seq-Basketball_v_Basketball_g10_c03.csv: 26
# num of samples from vid seq-Basketball_v_Basketball_g10_c04.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g10_c05.csv: 26
# num of samples from vid seq-Basketball_v_Basketball_g11_c01.csv: 23
# num of samples from vid seq-Basketball_v_Basketball_g11_c02.csv: 32
# num of samples from vid seq-Basketball_v_Basketball_g11_c03.csv: 15
# num of samples from vid seq-Basketball_v_Basketball_g11_c04.csv: 16
# num of samples from vid seq-Basketball_v_Basketball_g11_c05.csv: 18
# num of samples from vid seq-Basketball_v_Basketball_g12_c01.csv: 65
# num of samples from vid seq-Basketball_v_Basketball_g12_c02.csv: 43
# num of samples from vid seq-Basketball_v_Basketball_g12_c03.csv: 31
# num of samples from vid seq-Basketball_v_Basketball_g12_c04.csv: 54
# num of samples from vid seq-Basketball_v_Basketball_g12_c05.csv: 54
# num of samples from vid seq-Basketball_v_Basketball_g13_c01.csv: 71
# num of samples from vid seq-Basketball_v_Basketball_g13_c02.csv: 78
# num of samples from vid seq-Basketball_v_Basketball_g13_c03.csv: 74
# num of samples from vid seq-Basketball_v_Basketball_g13_c04.csv: 70
# num of samples from vid seq-Basketball_v_Basketball_g14_c01.csv: 17
# num of samples from vid seq-Basketball_v_Basketball_g14_c02.csv: 29
# num of samples from vid seq-Basketball_v_Basketball_g14_c03.csv: 19
# num of samples from vid seq-Basketball_v_Basketball_g14_c04.csv: 19
# num of samples from vid seq-Basketball_v_Basketball_g14_c05.csv: 19
# num of samples from vid seq-Basketball_v_Basketball_g15_c01.csv: 27
# num of samples from vid seq-Basketball_v_Basketball_g15_c02.csv: 35
# num of samples from vid seq-Basketball_v_Basketball_g15_c03.csv: 45
# num of samples from vid seq-Basketball_v_Basketball_g15_c04.csv: 25
# num of samples from vid seq-Basketball_v_Basketball_g15_c05.csv: 40
# num of samples from vid seq-Basketball_v_Basketball_g15_c06.csv: 43
# num of samples from vid seq-Basketball_v_Basketball_g15_c07.csv: 38
# num of samples from vid seq-Basketball_v_Basketball_g16_c01.csv: 117
# num of samples from vid seq-Basketball_v_Basketball_g16_c02.csv: 120
# num of samples from vid seq-Basketball_v_Basketball_g16_c03.csv: 28
# num of samples from vid seq-Basketball_v_Basketball_g16_c04.csv: 19
# num of samples from vid seq-Basketball_v_Basketball_g16_c05.csv: 108
# num of samples from vid seq-Basketball_v_Basketball_g16_c06.csv: 75
# num of samples from vid seq-Basketball_v_Basketball_g17_c01.csv: 35
# num of samples from vid seq-Basketball_v_Basketball_g17_c02.csv: 25
# num of samples from vid seq-Basketball_v_Basketball_g17_c03.csv: 50
# num of samples from vid seq-Basketball_v_Basketball_g17_c04.csv: 18
# num of samples from vid seq-Basketball_v_Basketball_g18_c01.csv: 56
# num of samples from vid seq-Basketball_v_Basketball_g18_c02.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g18_c03.csv: 40
# num of samples from vid seq-Basketball_v_Basketball_g18_c04.csv: 43
# num of samples from vid seq-Basketball_v_Basketball_g18_c05.csv: 32
# num of samples from vid seq-Basketball_v_Basketball_g19_c01.csv: 16
# num of samples from vid seq-Basketball_v_Basketball_g19_c02.csv: 32
# num of samples from vid seq-Basketball_v_Basketball_g19_c03.csv: 27
# num of samples from vid seq-Basketball_v_Basketball_g19_c04.csv: 26
# num of samples from vid seq-Basketball_v_Basketball_g19_c05.csv: 34
# num of samples from vid seq-Basketball_v_Basketball_g19_c06.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g19_c07.csv: 31
# num of samples from vid seq-Basketball_v_Basketball_g20_c01.csv: 27
# num of samples from vid seq-Basketball_v_Basketball_g20_c02.csv: 40
# num of samples from vid seq-Basketball_v_Basketball_g20_c03.csv: 23
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g20_c04.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g20_c05.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g20_c06.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g20_c07.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g21_c01.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g21_c02.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g21_c03.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g21_c04.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g21_c05.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g21_c06.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g22_c01.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g22_c02.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g22_c03.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g22_c04.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g22_c05.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g22_c06.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g22_c07.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g23_c01.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g23_c02.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g23_c03.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g23_c04.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g23_c05.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g23_c06.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g24_c01.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g24_c02.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g24_c03.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g24_c04.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g25_c01.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g25_c02.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g25_c03.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g25_c04.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g25_c05.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g25_c06.csv
# num of frames is less than temporal length; hence discarding this file-Basketball_v_Basketball_g25_c07.csv
# num of samples from vid seq-Biking_v_Biking_g01_c01.csv: 34
# num of samples from vid seq-Biking_v_Biking_g01_c02.csv: 34
# num of samples from vid seq-Biking_v_Biking_g01_c03.csv: 34
# num of samples from vid seq-Biking_v_Biking_g01_c04.csv: 42
# num of samples from vid seq-Biking_v_Biking_g02_c01.csv: 57
# num of samples from vid seq-Biking_v_Biking_g02_c02.csv: 57
# num of samples from vid seq-Biking_v_Biking_g02_c03.csv: 57
# num of samples from vid seq-Biking_v_Biking_g02_c04.csv: 57
# num of samples from vid seq-Biking_v_Biking_g02_c05.csv: 42
# num of samples from vid seq-Biking_v_Biking_g02_c06.csv: 56
# num of samples from vid seq-Biking_v_Biking_g02_c07.csv: 57
# num of samples from vid seq-Biking_v_Biking_g03_c01.csv: 91
# num of samples from vid seq-Biking_v_Biking_g03_c02.csv: 92
# num of samples from vid seq-Biking_v_Biking_g03_c03.csv: 86
# num of samples from vid seq-Biking_v_Biking_g03_c04.csv: 91
# num of samples from vid seq-Biking_v_Biking_g04_c01.csv: 57
# num of samples from vid seq-Biking_v_Biking_g04_c02.csv: 42
# num of samples from vid seq-Biking_v_Biking_g04_c03.csv: 57
# num of samples from vid seq-Biking_v_Biking_g04_c04.csv: 51
# num of samples from vid seq-Biking_v_Biking_g04_c05.csv: 50
# num of samples from vid seq-Biking_v_Biking_g05_c01.csv: 72
# num of samples from vid seq-Biking_v_Biking_g05_c02.csv: 47
# num of samples from vid seq-Biking_v_Biking_g05_c03.csv: 47
# num of samples from vid seq-Biking_v_Biking_g05_c04.csv: 47
# num of samples from vid seq-Biking_v_Biking_g05_c05.csv: 37
# num of samples from vid seq-Biking_v_Biking_g05_c06.csv: 42
# num of samples from vid seq-Biking_v_Biking_g05_c07.csv: 42
# num of samples from vid seq-Biking_v_Biking_g06_c01.csv: 22
# num of samples from vid seq-Biking_v_Biking_g06_c02.csv: 36
# num of samples from vid seq-Biking_v_Biking_g06_c03.csv: 47
# num of samples from vid seq-Biking_v_Biking_g06_c04.csv: 55
# num of samples from vid seq-Biking_v_Biking_g06_c05.csv: 47
# num of samples from vid seq-Biking_v_Biking_g07_c01.csv: 72
# num of samples from vid seq-Biking_v_Biking_g07_c02.csv: 87
# num of samples from vid seq-Biking_v_Biking_g07_c03.csv: 97
# num of samples from vid seq-Biking_v_Biking_g07_c04.csv: 71
# num of samples from vid seq-Biking_v_Biking_g07_c05.csv: 45
# num of samples from vid seq-Biking_v_Biking_g07_c06.csv: 57
# num of samples from vid seq-Biking_v_Biking_g08_c01.csv: 47
# num of samples from vid seq-Biking_v_Biking_g08_c02.csv: 27
# num of samples from vid seq-Biking_v_Biking_g08_c03.csv: 47
# num of samples from vid seq-Biking_v_Biking_g08_c04.csv: 47
# num of samples from vid seq-Biking_v_Biking_g08_c05.csv: 57
# num of samples from vid seq-Biking_v_Biking_g08_c06.csv: 57
# num of samples from vid seq-Biking_v_Biking_g09_c01.csv: 42
# num of samples from vid seq-Biking_v_Biking_g09_c02.csv: 42
# num of samples from vid seq-Biking_v_Biking_g09_c03.csv: 47
# num of samples from vid seq-Biking_v_Biking_g09_c04.csv: 46
# num of samples from vid seq-Biking_v_Biking_g10_c01.csv: 57
# num of samples from vid seq-Biking_v_Biking_g10_c02.csv: 57
# num of samples from vid seq-Biking_v_Biking_g10_c03.csv: 57
# num of samples from vid seq-Biking_v_Biking_g10_c04.csv: 57
# num of samples from vid seq-Biking_v_Biking_g10_c05.csv: 57
# num of samples from vid seq-Biking_v_Biking_g10_c06.csv: 57
# num of samples from vid seq-Biking_v_Biking_g11_c01.csv: 34
# num of samples from vid seq-Biking_v_Biking_g11_c02.csv: 34
# num of samples from vid seq-Biking_v_Biking_g11_c03.csv: 29
# num of samples from vid seq-Biking_v_Biking_g11_c04.csv: 49
# num of samples from vid seq-Biking_v_Biking_g11_c05.csv: 35
# num of samples from vid seq-Biking_v_Biking_g11_c06.csv: 35
# num of samples from vid seq-Biking_v_Biking_g12_c01.csv: 57
# num of samples from vid seq-Biking_v_Biking_g12_c02.csv: 47
# num of samples from vid seq-Biking_v_Biking_g12_c03.csv: 47
# num of samples from vid seq-Biking_v_Biking_g12_c04.csv: 47
# num of samples from vid seq-Biking_v_Biking_g13_c01.csv: 34
# num of samples from vid seq-Biking_v_Biking_g13_c02.csv: 34
# num of samples from vid seq-Biking_v_Biking_g13_c03.csv: 24
# num of samples from vid seq-Biking_v_Biking_g13_c04.csv: 57
# num of samples from vid seq-Biking_v_Biking_g13_c05.csv: 56
# num of samples from vid seq-Biking_v_Biking_g13_c06.csv: 37
# num of samples from vid seq-Biking_v_Biking_g14_c01.csv: 28
# num of samples from vid seq-Biking_v_Biking_g14_c02.csv: 39
# num of samples from vid seq-Biking_v_Biking_g14_c03.csv: 32
# num of samples from vid seq-Biking_v_Biking_g14_c04.csv: 36
# num of samples from vid seq-Biking_v_Biking_g15_c01.csv: 57
# num of samples from vid seq-Biking_v_Biking_g15_c02.csv: 57
# num of samples from vid seq-Biking_v_Biking_g15_c03.csv: 57
# num of samples from vid seq-Biking_v_Biking_g15_c04.csv: 57
# num of samples from vid seq-Biking_v_Biking_g15_c05.csv: 57
# num of samples from vid seq-Biking_v_Biking_g16_c01.csv: 57
# num of samples from vid seq-Biking_v_Biking_g16_c02.csv: 46
# num of samples from vid seq-Biking_v_Biking_g16_c03.csv: 38
# num of samples from vid seq-Biking_v_Biking_g16_c04.csv: 42
# num of samples from vid seq-Biking_v_Biking_g16_c05.csv: 57
# num of samples from vid seq-Biking_v_Biking_g17_c01.csv: 35
# num of samples from vid seq-Biking_v_Biking_g17_c02.csv: 57
# num of samples from vid seq-Biking_v_Biking_g17_c03.csv: 42
# num of samples from vid seq-Biking_v_Biking_g17_c04.csv: 48
# num of samples from vid seq-Biking_v_Biking_g17_c05.csv: 48
# num of samples from vid seq-Biking_v_Biking_g17_c06.csv: 57
# num of samples from vid seq-Biking_v_Biking_g18_c01.csv: 34
# num of samples from vid seq-Biking_v_Biking_g18_c02.csv: 42
# num of samples from vid seq-Biking_v_Biking_g18_c03.csv: 45
# num of samples from vid seq-Biking_v_Biking_g18_c04.csv: 42
# num of samples from vid seq-Biking_v_Biking_g18_c05.csv: 49
# num of samples from vid seq-Biking_v_Biking_g18_c06.csv: 57
# num of samples from vid seq-Biking_v_Biking_g19_c01.csv: 34
# num of samples from vid seq-Biking_v_Biking_g19_c02.csv: 34
# num of samples from vid seq-Biking_v_Biking_g19_c03.csv: 34
# num of samples from vid seq-Biking_v_Biking_g19_c04.csv: 34
# the exception:
# end of data generator
# num of samples from vid seq-Archery_v_Archery_g18_c03.csv: 46
# num of samples from vid seq-Archery_v_Archery_g18_c04.csv: 39
# num of samples from vid seq-Archery_v_Archery_g18_c05.csv: 35
# num of samples from vid seq-Archery_v_Archery_g18_c06.csv: 37
# num of samples from vid seq-Archery_v_Archery_g18_c07.csv: 32
# num of samples from vid seq-Archery_v_Archery_g19_c01.csv: 29
# num of samples from vid seq-Archery_v_Archery_g19_c02.csv: 19
# num of samples from vid seq-Archery_v_Archery_g19_c03.csv: 36
# num of samples from vid seq-Archery_v_Archery_g19_c04.csv: 20
# num of samples from vid seq-Archery_v_Archery_g20_c01.csv: 19
# num of samples from vid seq-Archery_v_Archery_g20_c02.csv: 18
# num of samples from vid seq-Archery_v_Archery_g20_c03.csv: 20
# num of samples from vid seq-Archery_v_Archery_g20_c04.csv: 21
# num of samples from vid seq-Archery_v_Archery_g20_c05.csv: 27
# num of samples from vid seq-Archery_v_Archery_g20_c06.csv: 26
# num of samples from vid seq-Archery_v_Archery_g20_c07.csv: 21
# num of samples from vid seq-Archery_v_Archery_g21_c01.csv: 22
# num of samples from vid seq-Archery_v_Archery_g21_c02.csv: 40
# num of samples from vid seq-Archery_v_Archery_g21_c03.csv: 51
# num of samples from vid seq-Archery_v_Archery_g21_c04.csv: 48
# num of samples from vid seq-Archery_v_Archery_g22_c01.csv: 13
# num of samples from vid seq-Archery_v_Archery_g22_c02.csv: 14
# num of samples from vid seq-Archery_v_Archery_g22_c03.csv: 19
# num of samples from vid seq-Archery_v_Archery_g22_c04.csv: 15
# num of samples from vid seq-Archery_v_Archery_g22_c05.csv: 14
# num of samples from vid seq-Archery_v_Archery_g23_c01.csv: 27
# num of samples from vid seq-Archery_v_Archery_g23_c02.csv: 25
# num of samples from vid seq-Archery_v_Archery_g23_c03.csv: 24
# num of samples from vid seq-Archery_v_Archery_g23_c04.csv: 23
# num of samples from vid seq-Archery_v_Archery_g23_c05.csv: 19
# num of samples from vid seq-Archery_v_Archery_g23_c06.csv: 18
# num of samples from vid seq-Archery_v_Archery_g23_c07.csv: 18
# num of samples from vid seq-Archery_v_Archery_g24_c01.csv: 19
# num of samples from vid seq-Archery_v_Archery_g24_c02.csv: 57
# num of samples from vid seq-Archery_v_Archery_g24_c03.csv: 24
# num of samples from vid seq-Archery_v_Archery_g24_c04.csv: 27
# num of samples from vid seq-Archery_v_Archery_g24_c05.csv: 28
# num of samples from vid seq-Archery_v_Archery_g24_c06.csv: 27
# num of samples from vid seq-Archery_v_Archery_g25_c01.csv: 49
# num of samples from vid seq-Archery_v_Archery_g25_c02.csv: 44
# num of samples from vid seq-Archery_v_Archery_g25_c03.csv: 47
# num of samples from vid seq-Archery_v_Archery_g25_c04.csv: 61
# num of samples from vid seq-Archery_v_Archery_g25_c05.csv: 48
# num of samples from vid seq-Archery_v_Archery_g25_c06.csv: 55
# num of samples from vid seq-Archery_v_Archery_g25_c07.csv: 30
# num of samples from vid seq-Basketball_v_Basketball_g20_c04.csv: 27
# num of samples from vid seq-Basketball_v_Basketball_g20_c05.csv: 27
# num of samples from vid seq-Basketball_v_Basketball_g20_c06.csv: 19
# num of samples from vid seq-Basketball_v_Basketball_g20_c07.csv: 15
# num of samples from vid seq-Basketball_v_Basketball_g21_c01.csv: 14
# num of samples from vid seq-Basketball_v_Basketball_g21_c02.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g21_c03.csv: 42
# num of samples from vid seq-Basketball_v_Basketball_g21_c04.csv: 29
# num of samples from vid seq-Basketball_v_Basketball_g21_c05.csv: 42
# num of samples from vid seq-Basketball_v_Basketball_g21_c06.csv: 18
# num of samples from vid seq-Basketball_v_Basketball_g22_c01.csv: 27
# num of samples from vid seq-Basketball_v_Basketball_g22_c02.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g22_c03.csv: 30
# num of samples from vid seq-Basketball_v_Basketball_g22_c04.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g22_c05.csv: 19
# num of samples from vid seq-Basketball_v_Basketball_g22_c06.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g22_c07.csv: 21
# num of samples from vid seq-Basketball_v_Basketball_g23_c01.csv: 31
# num of samples from vid seq-Basketball_v_Basketball_g23_c02.csv: 27
# num of samples from vid seq-Basketball_v_Basketball_g23_c03.csv: 27
# num of samples from vid seq-Basketball_v_Basketball_g23_c04.csv: 26
# num of samples from vid seq-Basketball_v_Basketball_g23_c05.csv: 22
# num of samples from vid seq-Basketball_v_Basketball_g23_c06.csv: 21
# num of samples from vid seq-Basketball_v_Basketball_g24_c01.csv: 30
# num of samples from vid seq-Basketball_v_Basketball_g24_c02.csv: 27
# num of samples from vid seq-Basketball_v_Basketball_g24_c03.csv: 26
# num of samples from vid seq-Basketball_v_Basketball_g24_c04.csv: 27
# num of samples from vid seq-Basketball_v_Basketball_g25_c01.csv: 28
# num of samples from vid seq-Basketball_v_Basketball_g25_c02.csv: 41
# num of samples from vid seq-Basketball_v_Basketball_g25_c03.csv: 33
# num of samples from vid seq-Basketball_v_Basketball_g25_c04.csv: 24
# num of samples from vid seq-Basketball_v_Basketball_g25_c05.csv: 42
# num of samples from vid seq-Basketball_v_Basketball_g25_c06.csv: 24
# num of samples from vid seq-Basketball_v_Basketball_g25_c07.csv: 29
# num of samples from vid seq-Biking_v_Biking_g20_c01.csv: 79
# num of samples from vid seq-Biking_v_Biking_g20_c02.csv: 82
# num of samples from vid seq-Biking_v_Biking_g20_c03.csv: 81
# num of samples from vid seq-Biking_v_Biking_g20_c04.csv: 78
# num of samples from vid seq-Biking_v_Biking_g20_c05.csv: 85
# num of samples from vid seq-Biking_v_Biking_g20_c06.csv: 86
# num of samples from vid seq-Biking_v_Biking_g20_c07.csv: 86
# num of samples from vid seq-Biking_v_Biking_g21_c01.csv: 57
# num of samples from vid seq-Biking_v_Biking_g21_c02.csv: 57
# num of samples from vid seq-Biking_v_Biking_g21_c03.csv: 27
# num of samples from vid seq-Biking_v_Biking_g21_c04.csv: 57
# num of samples from vid seq-Biking_v_Biking_g21_c05.csv: 48
# num of samples from vid seq-Biking_v_Biking_g21_c06.csv: 57
# num of samples from vid seq-Biking_v_Biking_g21_c07.csv: 42
# num of samples from vid seq-Biking_v_Biking_g22_c01.csv: 51
# num of samples from vid seq-Biking_v_Biking_g22_c02.csv: 32
# num of samples from vid seq-Biking_v_Biking_g22_c03.csv: 81
# num of samples from vid seq-Biking_v_Biking_g22_c04.csv: 99
# num of samples from vid seq-Biking_v_Biking_g22_c05.csv: 48
# num of samples from vid seq-Biking_v_Biking_g23_c01.csv: 130
# num of samples from vid seq-Biking_v_Biking_g23_c02.csv: 146
# num of samples from vid seq-Biking_v_Biking_g23_c03.csv: 109
# num of samples from vid seq-Biking_v_Biking_g23_c04.csv: 108
# num of samples from vid seq-Biking_v_Biking_g24_c01.csv: 42
# num of samples from vid seq-Biking_v_Biking_g24_c02.csv: 50
# num of samples from vid seq-Biking_v_Biking_g24_c03.csv: 38
# num of samples from vid seq-Biking_v_Biking_g24_c04.csv: 49
# num of samples from vid seq-Biking_v_Biking_g24_c05.csv: 57
# num of samples from vid seq-Biking_v_Biking_g24_c06.csv: 59
# num of samples from vid seq-Biking_v_Biking_g24_c07.csv: 42
# num of samples from vid seq-Biking_v_Biking_g25_c01.csv: 34
# num of samples from vid seq-Biking_v_Biking_g25_c02.csv: 34
# num of samples from vid seq-Biking_v_Biking_g25_c03.csv: 40
# num of samples from vid seq-Biking_v_Biking_g25_c04.csv: 47
# the exception:
# end of data generator

# %%
print('num of train_samples: {}'.format(len(train_data)))
print('num of test_samples: {}'.format(len(test_data)))
# Out:
# num of train_samples: 12277
# num of test_samples: 4472

# %%
train_generator = data_gen_obj.data_generator(train_data,batch_size=6,shuffle=True)

test_generator = data_gen_obj.data_generator(test_data,batch_size=6,shuffle=True)

# %%
def get_model(num_classes=Config.num_classes):
    # Define model
    model = Sequential()
    model.add(Conv3D(32, kernel_size=(3, 3, 3), input_shape=(
        16,64,64,3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv3D(32, kernel_size=(3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling3D(pool_size=(3, 3, 3), padding='same'))
    model.add(Dropout(0.25))

    model.add(Conv3D(64, kernel_size=(3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv3D(64, kernel_size=(3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling3D(pool_size=(3, 3, 3), padding='same'))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes))
    model.add(Activation("softmax"))
    model.compile(loss=categorical_crossentropy,
                  optimizer=Adam(), metrics=['accuracy'])
    model.summary()
    #plot_model(model, show_shapes=True,
    #           to_file='model.png')
    return model

# %%
model = get_model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 16, 64, 64, 32)    2624
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 64, 64, 32)    0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 16, 64, 64, 32)    27680
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 64, 64, 32)    0
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 6, 22, 22, 32)     0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 22, 22, 32)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 6, 22, 22, 64)     55360
# _________________________________________________________________
# activation_3 (Activation)    (None, 6, 22, 22, 64)     0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 6, 22, 22, 64)     110656
# _________________________________________________________________
# activation_4 (Activation)    (None, 6, 22, 22, 64)     0
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 2, 8, 8, 64)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 8, 8, 64)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 1539
# _________________________________________________________________
# activation_5 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 4,392,675
# Trainable params: 4,392,675
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model using generator
hist = model.fit_generator(test_generator, 
                steps_per_epoch=len(test_data),epochs=3)
# Out:
# Epoch 1/3
#  367/4472 [=>............................] - ETA: 9:33:32 - loss: 0.6343 - acc: 0.7598
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-74a9f36a5ce1> in <module>
#       1 # Fit model using generator
#       2 hist = model.fit_generator(test_generator,
# ----> 3                 steps_per_epoch=len(test_data),epochs=3)
#
# ~\AppData\Local\Continuum\Anaconda3\envs\keras_env\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\AppData\Local\Continuum\Anaconda3\envs\keras_env\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~\AppData\Local\Continuum\Anaconda3\envs\keras_env\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~\AppData\Local\Continuum\Anaconda3\envs\keras_env\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~\AppData\Local\Continuum\Anaconda3\envs\keras_env\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\AppData\Local\Continuum\Anaconda3\envs\keras_env\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\AppData\Local\Continuum\Anaconda3\envs\keras_env\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
